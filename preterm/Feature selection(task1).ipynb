# %%
import pandas as pd
import numpy as np

import os

from mrmr import mrmr_classif

# %% [markdown]
# # Load Data

# %%
BASEDIR = '../data'

metadata = pd.read_csv(
    os.path.join(BASEDIR, 'metadata', 'metadata.csv')
)

tax_genus = pd.read_csv(
    os.path.join(BASEDIR, 'taxonomy', 'taxonomy_relabd.genus.csv'),
)

pt_ra_1e_1 = pd.read_csv(
    os.path.join(BASEDIR, 'phylotypes', 'phylotype_relabd.1e_1.csv'),
)

sv_counts = pd.read_csv(
    os.path.join(BASEDIR, 'sv_counts', 'sp_sv_long.csv'),
)

meta = metadata[['specimen', 'participant_id', 'collect_wk']]

# %% [markdown]
# ## sv_counts for features

# %%
def sv_to_num(sv):
    try:
        num = int(sv.split('___')[1])
    except:
        num = None
    return num

def sv_for_features(df, index, cols):
    df['num_sv'] = df.sv.map(lambda x: sv_to_num(x))
    
    num_features = 53129
   
    features = []
    for specimen in index:
        feature = np.zeros(num_features)
        new_df = df[df['specimen'] == specimen]
        sv = np.array(new_df['num_sv'])
        fract = np.array(new_df['fract'])
        for i in range(len(sv)):
            if sv[i] == None:
                continue
            else:
                feature[sv[i]-1] = fract[i]
        features.append(feature)
    df_features = pd.DataFrame(features, index=index, columns = cols)
    df_features.index.name = 'specimen'
    return df_features

index = np.array(metadata.specimen)
sv_cols = np.load('../sv_cols.npy') # sorted sv array

new_sv = sv_for_features(sv_counts, index, sv_cols)

# %% [markdown]
# ## y_labels

# %%
y_df = metadata[['was_preterm', 'participant_id']]
y_df = y_df.drop_duplicates(['participant_id'], keep='first')
y_df = y_df.set_index('participant_id')

# %%
y_df
# Out:
#                 was_preterm
# participant_id
# A00001                False
# A00002                False
# A00003                False
# A00004                False
# A00005                False
# ...                     ...
# J00111                False
# J00112                False
# J00113                False
# J00115                False
# J00116                False
#
# [1268 rows x 1 columns]

# %% [markdown]
# # MRMR feature selection

# %%
meta = metadata[['specimen', 'participant_id', 'collect_wk']]

def get_mrmr(df, num = 300):
    df = pd.merge(meta, df, on='specimen')
    df = df[df['collect_wk'] <= 32] # For preterm
    dup = df.duplicated('participant_id', keep=False)
    duplicated = df[dup]
    dup_mean = duplicated.groupby(['participant_id'], as_index=False).aggregate(np.mean)
    df = df.drop_duplicates(['participant_id'], keep=False)
    df = pd.concat([df, dup_mean])
    df = df.sort_values(by=['participant_id'], ascending=[True]) 
    df = df.set_index('participant_id')
    df = df.drop(columns = ['specimen', 'collect_wk'])
    
    selected_features = mrmr_classif(X=df, y=y_df.loc[df.index], K=num)
    
    return selected_features

# %%
tax_selected_features = get_mrmr(tax_genus)
tax_selected_features
# Out:
# 100%|██████████| 300/300 [01:47<00:00,  2.79it/s]
# ['Prevotella',
#  'Ureaplasma',
#  'Jeotgalicoccus',
#  'Atopobiaceae/Coriobacteriaceae',
#  'Chryseobacterium',
#  'Pelomonas',
#  'Enterobacteriaceae',
#  'Haemophilus',
#  'Yokenella',
#  'Citrobacter/Kluyvera',
#  'Dorea/Butyrivibrio',
#  'Streptococcus',
#  'Desulfatiglans',
#  'Pseudomonadales/Acidimicrobiales',
#  'Lactobacillales',
#  'Cyanobacteria',
#  'Candidatus Paracaedibacter',
#  'Cryptobacterium',
#  'Holosporaceae/Rickettsiaceae',
#  'Pseudobutyrivibrio/Butyrivibrio',
#  'Alcanivorax',
#  'Corynebacteriaceae/Lachnospiraceae',
#  'Rhodobacteraceae/Clostridiales_Family_XIII._Incertae_Sedis',
#  'Psychrobacter',
#  'Pseudoramibacter',
#  'Tardiphaga',
#  'Mesorhizobium',
#  'Bacteroides/Prevotella',
#  'Geodermatophilus',
#  'Luteitalea',
#  'Spirochaetaceae/Desulfobacteraceae',
#  'Ciceribacter',
#  'Agaricicola',
#  'Mycoplasmataceae/Hungateiclostridiaceae',
#  'Alphaproteobacteria/Erysipelotrichia',
#  'Marinobacter',
#  'Phyllobacterium',
#  'Flavobacterium/Oligella',
#  'Atopobium/Fusobacterium',
#  'Deinococci/Acidobacteriia',
#  'Spirochaetaceae/Coriobacteriaceae',
#  'Pseudomonadaceae/Eggerthellaceae',
#  'Peptostreptococcus',
#  'Deinococci',
#  'Methylobacteriaceae',
#  'Friedmanniella',
#  'Mobiluncus',
#  'Anaeroglobus',
#  'Dermabacter',
#  'Varibaculum/Neisseria',
#  'Anaerosphaera',
#  'Xanthomonas',
#  'Lacrimispora',
#  'Methylorubrum',
#  'Lachnospiraceae/Mycoplasmataceae',
#  'Oxalobacteraceae',
#  'Sporobacter',
#  'Aeribacillus',
#  'Helicobacter',
#  'cellular organisms',
#  'Cellvibrionaceae',
#  'Tidjanibacter',
#  'Methyloversatilis',
#  'Stomatobaculum',
#  'Actinotignum',
#  'Sneathia',
#  'Rhodobacteraceae/Phyllobacteriaceae',
#  'Coprobacillus',
#  'Tyzzerella/Coprococcus',
#  'Peptococcus',
#  'Mycoplasma',
#  'Vallitalea/Corynebacterium',
#  'Faecalitalea',
#  'Carnobacteriaceae',
#  'Aureimonas',
#  'Akkermansia',
#  'Conchiformibius',
#  'Alloscardovia',
#  'Frankia',
#  'Halomonas',
#  'Planococcaceae',
#  'PVC_group/FCB_group/Terrabacteria_group',
#  'Mitsuokella',
#  'Odoribacteraceae',
#  'Eggerthellaceae/Coriobacteriaceae',
#  'Rhodanobacter',
#  'Collinsella',
#  'Cronobacter',
#  'Chelatococcus',
#  'Marinilabiliales',
#  'Flavobacteriales',
#  'Leucobacter',
#  'Proteobacteria/Chloroflexi_<Chloroflexi>',
#  'Escherichia/Shigella',
#  'Sphingobacteriaceae',
#  'Adhaeribacter',
#  'Paeniclostridium',
#  'Pseudolabrys',
#  'Murdochiella',
#  'Thermoanaerobacterales',
#  'Fusobacterium',
#  'Bacteroidia/Planctomycetia',
#  'unclassified Tissierellia',
#  'Nostocales',
#  'Rhodoluna',
#  'Methylobacillus',
#  'Moryella',
#  'Gulosibacter',
#  'Chloroflexi_<Chloroflexi>/Tenericutes',
#  'Arcanobacterium',
#  'Eubacterium/Coprococcus',
#  'Parascardovia',
#  'Desulfobacterales/Campylobacterales',
#  'Chroococcales/Synergistales',
#  'Peptoniphilus',
#  'Aquirufa',
#  'Bacteroidetes/Chlorobi group',
#  'Bacillales incertae sedis',
#  'Sphingobacterium',
#  'Leuconostoc',
#  'Neisseria',
#  'Shigella',
#  'Sphingomonas',
#  'Dechloromonas',
#  'Peptococcaceae/Thermoanaerobacteraceae',
#  'Flavobacteriia/Spartobacteria/Deltaproteobacteria',
#  'Actinomyces/Corynebacterium',
#  'Chlamydia',
#  'Spirochaetaceae',
#  'Hungateiclostridiaceae',
#  'Cutibacterium',
#  'Tissierellaceae',
#  'Rhodobacteraceae/Cardiobacteriaceae',
#  'unclassified Clostridiales',
#  'Longibaculum',
#  'Schaalia',
#  'Planctomycetes_<Planctomycetes>/Acidobacteria_<Acidobacteria>',
#  'Howardella',
#  'Bacillus <firmicutes>',
#  'Serratia',
#  'Cloacibacillus',
#  'Xanthobacteraceae/Hyphomicrobiaceae',
#  'Brevibacteriaceae/Microbacteriaceae',
#  'Rickettsia',
#  'Actinomycetaceae',
#  'Rhizobium/Agrobacterium group',
#  'Clostridiaceae/Ruminococcaceae',
#  'Spiroplasma',
#  'Streptococcaceae',
#  'Thermostilla',
#  'Merdibacter',
#  'Monoglobus',
#  'Prolinoborus/Acinetobacter',
#  'Eremococcus <firmicutes>',
#  'Deltaproteobacteria/Phycisphaerae',
#  'Caecibacter',
#  'Lactobacillus',
#  'Moraxella',
#  'Massilistercora',
#  'Enterobacter/Klebsiella',
#  'Cytophagaceae',
#  'Duncaniella',
#  'Aerococcus/Lactobacillus',
#  'Chitinophagaceae/Sphingobacteriaceae',
#  'Porphyromonadaceae/Chitinophagaceae',
#  'Rikenellaceae',
#  'Veillonella',
#  'Chelatococcus/Hyphomicrobium',
#  'Herbaspirillum',
#  'Curvibacter/Comamonas',
#  'Flavobacteriia/Spartobacteria',
#  'Prevotellaceae/Chitinophagaceae',
#  'Pasteurellaceae',
#  'Absiella',
#  'Galactobacillus',
#  'Erysipelotrichaceae/Ruminococcaceae',
#  'Olsenella/Atopobium',
#  'Candidatus_Pelagibacter/Roseburia',
#  'Planococcus_<firmicutes>/Varibaculum',
#  'Muribaculaceae/Barnesiellaceae',
#  'Bittarella',
#  'Phreatobacter',
#  'Afipia',
#  'Planctomycetes_<Planctomycetes>/Euryarchaeota',
#  'Kosakonia',
#  'Ruminococcus',
#  'Enterobacter/Escherichia',
#  'Oscillatoriophycideae',
#  'Comamonas',
#  'Prevotellaceae/Bacteroidaceae',
#  'Mucilaginibacter',
#  'Candidatus Planktophila',
#  'Odoribacter',
#  'Bulleidia',
#  'Aeromonadales',
#  'Butyricicoccus',
#  'Oceanicola',
#  'Shuttleworthia',
#  'Dyadobacter',
#  'Candidatus Paracaedibacteraceae',
#  'Barnesiellaceae',
#  'Negativicutes',
#  'Pantoea/Enterobacter',
#  'Oscillatoriaceae/Acetobacteraceae',
#  'Erysipelotrichales',
#  'Lachnospiraceae/Hungateiclostridiaceae/Vallitaleaceae',
#  'Deinococcales',
#  'Flavobacteriia/Deltaproteobacteria',
#  'unclassified Betaproteobacteria',
#  'Tenericutes',
#  'Alcaligenaceae/Caulobacteraceae',
#  'Aggregatibacter',
#  'Dysgonomonas',
#  'Verrucomicrobiae/Planctomycetia',
#  'Deltaproteobacteria',
#  'Spirochaetaceae/Porphyromonadaceae/Prevotellaceae',
#  'Microvirga/Ureaplasma',
#  'Massilia/Oligella',
#  'Leptotrichiaceae/Lachnospiraceae',
#  'Tyzzerella/Corynebacterium',
#  'Proteobacteria/Chloroflexi_<Chloroflexi>/Planctomycetes_<Planctomycetes>',
#  'Candidatus_Pelagibacter/Rubellimicrobium',
#  'Petrimonas',
#  'Trueperella',
#  'Clostridiales incertae sedis',
#  'Oligoflexia/Deltaproteobacteria',
#  'Bacillaceae/Ruminococcaceae',
#  'Porphyromonadaceae/Oscillatoriaceae',
#  'Spirochaetes <Spirochaetes>',
#  'Schwartzia <firmicutes>',
#  'Raoultella',
#  'Flectobacillus',
#  'Microbacteriaceae',
#  'Rhizobiaceae',
#  'Salinicoccus',
#  'Hydrocarboniphaga',
#  'Desulfobacteraceae/Holosporaceae',
#  'Campylobacteraceae/Leuconostocaceae',
#  'Roseomonas',
#  'Acidovorax',
#  'Methanobrevibacter',
#  'Phycisphaerae',
#  'Chlamydiia/Alphaproteobacteria',
#  'Fluviicola',
#  'Chroococcales/Mycoplasmatales',
#  'Intestinibacillus',
#  'Gemmatimonas',
#  'Agrobacterium',
#  'Coxiellaceae',
#  'Azotobacter',
#  'Kineothrix',
#  'Peptoniphilaceae',
#  'Lactococcus/Varibaculum',
#  'Oscillatoriales/Verrucomicrobiales',
#  'Bacteroidales/Fusobacteriales',
#  'Spirochaeta',
#  'Pontibacter',
#  'Alteromonadaceae',
#  'Prevotellamassilia',
#  'Khoudiadiopia',
#  'Aerococcus',
#  'Staphylococcus',
#  'Afipia/Bradyrhizobium',
#  'Eikenella',
#  'Sediminibacterium',
#  'Candidatus_Pelagibacter/Prevotella',
#  'Granulicatella',
#  'Morococcus/Neisseria',
#  'Microbacterium',
#  'Escherichia',
#  'Chloroflexi_<Chloroflexi>/Planctomycetes_<Planctomycetes>',
#  'Comamonadaceae',
#  'Petrimonas/Porphyromonas',
#  'Slackia',
#  'Oligoflexia/Bacilli',
#  'Paracoccus <a-proteobacteria>',
#  'Bacilli',
#  'Chryseobacterium/Bergeyella',
#  'Pseudacidovorax',
#  'Algisphaera',
#  'Oligella',
#  'Nitrosomonadaceae',
#  'Christensenellaceae',
#  'Sutterella',
#  'Proteobacteria/Planctomycetes_<Planctomycetes>',
#  'Knoellia',
#  'Rhodococcus <high GC Gram+>',
#  'Arcobacter',
#  'Telluria',
#  'Clavibacter',
#  'Kluyvera',
#  'Moheibacter',
#  'Firmicutes/Planctomycetes_<Planctomycetes>',
#  'Peptostreptococcaceae/Clostridiaceae',
#  'Planctomycetes_<Planctomycetes>/Bacteroidetes_<Bacteroidetes>',
#  'Enterococcus',
#  'Candidatus Hydrogenosomobacter',
#  'Rahnella',
#  'Xylophilus',
#  'Paludibaculum']

# %%
pt_selected_features = get_mrmr(pt_ra_1e_1)
pt_selected_features
# Out:
# 100%|██████████| 300/300 [08:21<00:00,  1.67s/it]
# ['pt__00019',
#  'pt__04975',
#  'pt__00371',
#  'pt__07247',
#  'pt__09501',
#  'pt__00702',
#  'pt__00920',
#  'pt__08646',
#  'pt__00903',
#  'pt__01216',
#  'pt__00838',
#  'pt__02916',
#  'pt__00135',
#  'pt__00036',
#  'pt__00589',
#  'pt__01556',
#  'pt__04090',
#  'pt__06530',
#  'pt__08014',
#  'pt__03486',
#  'pt__01471',
#  'pt__00986',
#  'pt__01321',
#  'pt__07701',
#  'pt__01489',
#  'pt__02445',
#  'pt__06816',
#  'pt__01600',
#  'pt__00889',
#  'pt__07723',
#  'pt__00342',
#  'pt__01081',
#  'pt__01474',
#  'pt__01431',
#  'pt__00981',
#  'pt__00178',
#  'pt__00987',
#  'pt__03566',
#  'pt__00532',
#  'pt__00201',
#  'pt__00583',
#  'pt__09505',
#  'pt__09016',
#  'pt__01376',
#  'pt__08467',
#  'pt__03241',
#  'pt__02466',
#  'pt__08818',
#  'pt__01935',
#  'pt__06720',
#  'pt__00433',
#  'pt__06508',
#  'pt__06674',
#  'pt__01798',
#  'pt__04820',
#  'pt__06776',
#  'pt__08366',
#  'pt__05507',
#  'pt__06309',
#  'pt__01270',
#  'pt__08517',
#  'pt__03039',
#  'pt__01909',
#  'pt__03791',
#  'pt__07551',
#  'pt__01936',
#  'pt__01901',
#  'pt__01088',
#  'pt__01240',
#  'pt__03223',
#  'pt__00482',
#  'pt__04184',
#  'pt__08932',
#  'pt__02214',
#  'pt__08754',
#  'pt__09264',
#  'pt__03509',
#  'pt__03673',
#  'pt__08307',
#  'pt__08719',
#  'pt__07966',
#  'pt__06210',
#  'pt__07806',
#  'pt__08194',
#  'pt__06870',
#  'pt__03439',
#  'pt__05150',
#  'pt__01519',
#  'pt__06043',
#  'pt__09441',
#  'pt__05021',
#  'pt__02319',
#  'pt__02918',
#  'pt__06727',
#  'pt__04194',
#  'pt__06670',
#  'pt__07841',
#  'pt__06612',
#  'pt__07564',
#  'pt__03805',
#  'pt__01693',
#  'pt__00529',
#  'pt__08557',
#  'pt__03082',
#  'pt__03320',
#  'pt__09013',
#  'pt__09096',
#  'pt__09396',
#  'pt__02143',
#  'pt__00519',
#  'pt__03940',
#  'pt__09665',
#  'pt__02178',
#  'pt__09398',
#  'pt__01955',
#  'pt__07986',
#  'pt__02874',
#  'pt__03994',
#  'pt__06874',
#  'pt__01083',
#  'pt__06222',
#  'pt__07864',
#  'pt__02517',
#  'pt__05033',
#  'pt__04992',
#  'pt__03185',
#  'pt__01349',
#  'pt__00844',
#  'pt__01760',
#  'pt__05787',
#  'pt__09140',
#  'pt__05845',
#  'pt__04165',
#  'pt__00403',
#  'pt__08016',
#  'pt__00438',
#  'pt__02023',
#  'pt__05693',
#  'pt__03906',
#  'pt__03707',
#  'pt__08077',
#  'pt__02805',
#  'pt__03759',
#  'pt__01200',
#  'pt__00008',
#  'pt__06326',
#  'pt__08217',
#  'pt__08522',
#  'pt__06616',
#  'pt__08302',
#  'pt__05731',
#  'pt__06484',
#  'pt__01862',
#  'pt__02612',
#  'pt__03611',
#  'pt__00045',
#  'pt__00657',
#  'pt__05506',
#  'pt__08405',
#  'pt__04077',
#  'pt__05906',
#  'pt__02235',
#  'pt__00013',
#  'pt__02580',
#  'pt__00815',
#  'pt__06947',
#  'pt__06303',
#  'pt__01467',
#  'pt__00151',
#  'pt__01455',
#  'pt__00192',
#  'pt__00670',
#  'pt__00332',
#  'pt__08028',
#  'pt__01572',
#  'pt__00772',
#  'pt__02407',
#  'pt__01174',
#  'pt__08031',
#  'pt__00593',
#  'pt__00009',
#  'pt__07775',
#  'pt__03531',
#  'pt__03063',
#  'pt__00206',
#  'pt__07777',
#  'pt__09469',
#  'pt__00090',
#  'pt__04347',
#  'pt__00166',
#  'pt__00755',
#  'pt__08995',
#  'pt__06119',
#  'pt__06331',
#  'pt__06236',
#  'pt__02689',
#  'pt__01063',
#  'pt__08032',
#  'pt__06358',
#  'pt__00470',
#  'pt__00430',
#  'pt__00025',
#  'pt__02067',
#  'pt__00197',
#  'pt__08059',
#  'pt__03918',
#  'pt__00448',
#  'pt__01286',
#  'pt__03425',
#  'pt__01518',
#  'pt__01814',
#  'pt__00058',
#  'pt__00110',
#  'pt__08647',
#  'pt__08667',
#  'pt__07608',
#  'pt__08640',
#  'pt__06206',
#  'pt__01075',
#  'pt__03268',
#  'pt__03652',
#  'pt__00179',
#  'pt__00068',
#  'pt__00355',
#  'pt__00439',
#  'pt__01908',
#  'pt__05232',
#  'pt__00374',
#  'pt__08006',
#  'pt__00649',
#  'pt__03750',
#  'pt__05553',
#  'pt__00086',
#  'pt__00745',
#  'pt__02618',
#  'pt__07625',
#  'pt__01178',
#  'pt__01606',
#  'pt__00041',
#  'pt__00511',
#  'pt__01662',
#  'pt__01126',
#  'pt__02225',
#  'pt__00055',
#  'pt__04927',
#  'pt__00449',
#  'pt__00746',
#  'pt__01966',
#  'pt__00557',
#  'pt__03344',
#  'pt__00127',
#  'pt__02956',
#  'pt__06005',
#  'pt__00334',
#  'pt__03019',
#  'pt__02493',
#  'pt__00458',
#  'pt__09332',
#  'pt__07200',
#  'pt__00947',
#  'pt__09531',
#  'pt__01366',
#  'pt__00126',
#  'pt__02505',
#  'pt__00022',
#  'pt__00072',
#  'pt__03168',
#  'pt__03789',
#  'pt__00853',
#  'pt__00250',
#  'pt__01354',
#  'pt__02400',
#  'pt__00813',
#  'pt__00034',
#  'pt__00814',
#  'pt__01001',
#  'pt__01491',
#  'pt__00039',
#  'pt__00912',
#  'pt__00108',
#  'pt__04106',
#  'pt__05040',
#  'pt__01585',
#  'pt__08041',
#  'pt__06057',
#  'pt__06137',
#  'pt__00644',
#  'pt__04750',
#  'pt__07274',
#  'pt__02981',
#  'pt__07693',
#  'pt__00071',
#  'pt__00104',
#  'pt__04948',
#  'pt__08560',
#  'pt__01846',
#  'pt__01433',
#  'pt__01006',
#  'pt__01194',
#  'pt__00235']

# %%
sv_selected_features = get_mrmr(new_sv)
sv_selected_features
# Out:
# 100%|██████████| 300/300 [38:59<00:00,  7.80s/it]
# ['combinedsv___33040',
#  'combinedsv___32987',
#  'combinedsv___36074',
#  'combinedsv___35780',
#  'combinedsv___34460',
#  'combinedsv___35463',
#  'combinedsv___44564',
#  'combinedsv___33107',
#  'combinedsv___28929',
#  'combinedsv___6990',
#  'combinedsv___1716',
#  'combinedsv___34614',
#  'combinedsv___26244',
#  'combinedsv___19868',
#  'combinedsv___3556',
#  'combinedsv___33615',
#  'combinedsv___35539',
#  'combinedsv___17753',
#  'combinedsv___35434',
#  'combinedsv___33483',
#  'combinedsv___33226',
#  'combinedsv___45226',
#  'combinedsv___32420',
#  'combinedsv___51675',
#  'combinedsv___20132',
#  'combinedsv___51997',
#  'combinedsv___32665',
#  'combinedsv___7722',
#  'combinedsv___6830',
#  'combinedsv___20322',
#  'combinedsv___51074',
#  'combinedsv___40870',
#  'combinedsv___50676',
#  'combinedsv___13060',
#  'combinedsv___20425',
#  'combinedsv___36117',
#  'combinedsv___30212',
#  'combinedsv___20683',
#  'combinedsv___34318',
#  'combinedsv___8512',
#  'combinedsv___6484',
#  'combinedsv___52933',
#  'combinedsv___35357',
#  'combinedsv___23314',
#  'combinedsv___46092',
#  'combinedsv___20452',
#  'combinedsv___39045',
#  'combinedsv___33577',
#  'combinedsv___18169',
#  'combinedsv___33594',
#  'combinedsv___33443',
#  'combinedsv___46915',
#  'combinedsv___20445',
#  'combinedsv___13371',
#  'combinedsv___2023',
#  'combinedsv___29688',
#  'combinedsv___44908',
#  'combinedsv___7597',
#  'combinedsv___44749',
#  'combinedsv___34111',
#  'combinedsv___34761',
#  'combinedsv___3777',
#  'combinedsv___39404',
#  'combinedsv___20271',
#  'combinedsv___9251',
#  'combinedsv___35623',
#  'combinedsv___23897',
#  'combinedsv___11347',
#  'combinedsv___33565',
#  'combinedsv___47334',
#  'combinedsv___47761',
#  'combinedsv___34774',
#  'combinedsv___32992',
#  'combinedsv___39578',
#  'combinedsv___42791',
#  'combinedsv___35720',
#  'combinedsv___47716',
#  'combinedsv___52967',
#  'combinedsv___5218',
#  'combinedsv___41877',
#  'combinedsv___20348',
#  'combinedsv___20524',
#  'combinedsv___19953',
#  'combinedsv___20379',
#  'combinedsv___30964',
#  'combinedsv___48375',
#  'combinedsv___35044',
#  'combinedsv___20414',
#  'combinedsv___21955',
#  'combinedsv___51545',
#  'combinedsv___48080',
#  'combinedsv___50836',
#  'combinedsv___35840',
#  'combinedsv___51795',
#  'combinedsv___5678',
#  'combinedsv___49248',
#  'combinedsv___11516',
#  'combinedsv___16379',
#  'combinedsv___51889',
#  'combinedsv___52950',
#  'combinedsv___49501',
#  'combinedsv___50465',
#  'combinedsv___51760',
#  'combinedsv___52909',
#  'combinedsv___5165',
#  'combinedsv___16100',
#  'combinedsv___29273',
#  'combinedsv___49521',
#  'combinedsv___20494',
#  'combinedsv___45873',
#  'combinedsv___15538',
#  'combinedsv___5970',
#  'combinedsv___22191',
#  'combinedsv___34236',
#  'combinedsv___23701',
#  'combinedsv___32725',
#  'combinedsv___52970',
#  'combinedsv___32465',
#  'combinedsv___36297',
#  'combinedsv___48030',
#  'combinedsv___32247',
#  'combinedsv___32618',
#  'combinedsv___36201',
#  'combinedsv___48664',
#  'combinedsv___32190',
#  'combinedsv___36369',
#  'combinedsv___51620',
#  'combinedsv___34371',
#  'combinedsv___6049',
#  'combinedsv___20296',
#  'combinedsv___24855',
#  'combinedsv___53017',
#  'combinedsv___32750',
#  'combinedsv___28825',
#  'combinedsv___34183',
#  'combinedsv___22563',
#  'combinedsv___1181',
#  'combinedsv___41941',
#  'combinedsv___48042',
#  'combinedsv___7228',
#  'combinedsv___27012',
#  'combinedsv___19490',
#  'combinedsv___1825',
#  'combinedsv___47434',
#  'combinedsv___43898',
#  'combinedsv___18080',
#  'combinedsv___12869',
#  'combinedsv___20172',
#  'combinedsv___19784',
#  'combinedsv___27812',
#  'combinedsv___44123',
#  'combinedsv___21796',
#  'combinedsv___29006',
#  'combinedsv___36406',
#  'combinedsv___43426',
#  'combinedsv___43920',
#  'combinedsv___12500',
#  'combinedsv___1201',
#  'combinedsv___25896',
#  'combinedsv___14383',
#  'combinedsv___32569',
#  'combinedsv___32409',
#  'combinedsv___45392',
#  'combinedsv___32532',
#  'combinedsv___19983',
#  'combinedsv___33160',
#  'combinedsv___33024',
#  'combinedsv___9570',
#  'combinedsv___46834',
#  'combinedsv___6713',
#  'combinedsv___41545',
#  'combinedsv___12926',
#  'combinedsv___20405',
#  'combinedsv___44813',
#  'combinedsv___32566',
#  'combinedsv___6485',
#  'combinedsv___11633',
#  'combinedsv___47331',
#  'combinedsv___32517',
#  'combinedsv___32726',
#  'combinedsv___33842',
#  'combinedsv___32966',
#  'combinedsv___20295',
#  'combinedsv___1394',
#  'combinedsv___53107',
#  'combinedsv___31126',
#  'combinedsv___46858',
#  'combinedsv___21799',
#  'combinedsv___20285',
#  'combinedsv___20395',
#  'combinedsv___53069',
#  'combinedsv___32549',
#  'combinedsv___36068',
#  'combinedsv___43603',
#  'combinedsv___32578',
#  'combinedsv___52959',
#  'combinedsv___32523',
#  'combinedsv___36284',
#  'combinedsv___33745',
#  'combinedsv___40024',
#  'combinedsv___44455',
#  'combinedsv___48033',
#  'combinedsv___53020',
#  'combinedsv___20698',
#  'combinedsv___20717',
#  'combinedsv___32238',
#  'combinedsv___32724',
#  'combinedsv___39996',
#  'combinedsv___52938',
#  'combinedsv___53068',
#  'combinedsv___43600',
#  'combinedsv___53060',
#  'combinedsv___32240',
#  'combinedsv___32511',
#  'combinedsv___8986',
#  'combinedsv___36346',
#  'combinedsv___46893',
#  'combinedsv___20464',
#  'combinedsv___13645',
#  'combinedsv___39653',
#  'combinedsv___39323',
#  'combinedsv___35432',
#  'combinedsv___47944',
#  'combinedsv___14516',
#  'combinedsv___33324',
#  'combinedsv___39490',
#  'combinedsv___27129',
#  'combinedsv___16578',
#  'combinedsv___7183',
#  'combinedsv___35912',
#  'combinedsv___0049',
#  'combinedsv___27842',
#  'combinedsv___0554',
#  'combinedsv___34745',
#  'combinedsv___40021',
#  'combinedsv___44470',
#  'combinedsv___33129',
#  'combinedsv___9357',
#  'combinedsv___34210',
#  'combinedsv___30855',
#  'combinedsv___17591',
#  'combinedsv___34749',
#  'combinedsv___24588',
#  'combinedsv___43860',
#  'combinedsv___0492',
#  'combinedsv___12059',
#  'combinedsv___34757',
#  'combinedsv___32114',
#  'combinedsv___32955',
#  'combinedsv___35407',
#  'combinedsv___33759',
#  'combinedsv___22617',
#  'combinedsv___33839',
#  'combinedsv___33832',
#  'combinedsv___35493',
#  'combinedsv___17609',
#  'combinedsv___34509',
#  'combinedsv___20714',
#  'combinedsv___6863',
#  'combinedsv___9253',
#  'combinedsv___34310',
#  'combinedsv___25858',
#  'combinedsv___24573',
#  'combinedsv___34750',
#  'combinedsv___34859',
#  'combinedsv___34211',
#  'combinedsv___13486',
#  'combinedsv___33349',
#  'combinedsv___29002',
#  'combinedsv___11702',
#  'combinedsv___33556',
#  'combinedsv___33434',
#  'combinedsv___34219',
#  'combinedsv___32375',
#  'combinedsv___6026',
#  'combinedsv___20728',
#  'combinedsv___34570',
#  'combinedsv___34276',
#  'combinedsv___4070',
#  'combinedsv___34323',
#  'combinedsv___11333',
#  'combinedsv___35869',
#  'combinedsv___31934',
#  'combinedsv___47953',
#  'combinedsv___2318',
#  'combinedsv___35042',
#  'combinedsv___21875',
#  'combinedsv___44466',
#  'combinedsv___34560',
#  'combinedsv___2006',
#  'combinedsv___34292',
#  'combinedsv___35865',
#  'combinedsv___33300',
#  'combinedsv___33083',
#  'combinedsv___24581',
#  'combinedsv___9368',
#  'combinedsv___33651',
#  'combinedsv___26324',
#  'combinedsv___42805',
#  'combinedsv___25454']

# %%
all_features = np.array(tax_selected_features + pt_selected_features + sv_selected_features)
np.save('selected_features.npy', all_features)
