# %%
import pandas as pd
import numpy as np
import random
import os
import warnings

from sklearn.model_selection import StratifiedKFold
from lazypredict.Supervised import LazyClassifier

warnings.simplefilter("ignore", UserWarning)
# warnings.simplefilter("ignore", DataConversionWarning)
warnings.simplefilter("ignore", FutureWarning)
# Out:
# /home/qoeogns09/miniconda3/envs/KBJ-preterm/lib/python3.7/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# # Load Data

# %%
BASEDIR = '../data'

metadata = pd.read_csv(
    os.path.join(BASEDIR, 'metadata', 'metadata.csv')
)

tax_genus = pd.read_csv(
    os.path.join(BASEDIR, 'taxonomy', 'taxonomy_relabd.genus.csv'),
)

pt_ra_1e_1 = pd.read_csv(
    os.path.join(BASEDIR, 'phylotypes', 'phylotype_relabd.1e_1.csv'),
)

alpha = pd.read_csv(
    os.path.join(BASEDIR, 'alpha_diversity', 'alpha_diversity.csv'),
)

cst = pd.read_csv(
    os.path.join(BASEDIR, 'community_state_types', 'cst_valencia.csv'),
)

sv_counts = pd.read_csv(
    os.path.join(BASEDIR, 'sv_counts', 'sp_sv_long.csv'),
)

# %%
race_meta = pd.read_csv(
    os.path.join(BASEDIR, 'metadata', 'metadata_normalized.csv')
)

meta = metadata[['specimen', 'participant_id', 'collect_wk']]

index = np.array(meta.specimen)

# %% [markdown]
# ## sv_counts for features

# %%
def sv_to_num(sv):
    try:
        num = int(sv.split('___')[1])
    except:
        num = None
    return num

def sv_for_features(df, index, cols):
    df['num_sv'] = df.sv.map(lambda x: sv_to_num(x))
    
    num_features = 53129
   
    features = []
    for specimen in index:
        feature = np.zeros(num_features)
        new_df = df[df['specimen'] == specimen]
        sv = np.array(new_df['num_sv'])
        fract = np.array(new_df['fract'])
        for i in range(len(sv)):
            if sv[i] == None:
                continue
            else:
                feature[sv[i]-1] = fract[i]
        features.append(feature)
    df_features = pd.DataFrame(features, index=index, columns = cols)
    df_features.index.name = 'specimen'
    return df_features

index = np.array(metadata.specimen)
sv_cols = np.load('../sv_cols.npy') # sorted sv array

new_sv = sv_for_features(sv_counts, index, sv_cols)

# %% [markdown]
# ## Merge all df

# %%
def merge_df(A):
    df = A[0]
    for i in range(1, len(A)):
        df = pd.merge(df, A[i], on='specimen')
    return df

# %%
meta = metadata[['specimen', 'participant_id', 'collect_wk']]
race_meta = race_meta[['Race: American Indian or Alaska Native', 'Race: Asian',
                       'Race: Black or African American',
                       'Race: Native Hawaiian or Other Pacific Islander', 'Race: Unknown',
                       'Race: White', 'specimen']]

df = merge_df([meta, tax_genus, pt_ra_1e_1, alpha, cst, new_sv, race_meta])
df = df[df['collect_wk'] <= 32]
# df = df.set_index('specimen')
df = df.drop(columns = ['CST', 'subCST', 'specimen', 'collect_wk'])

dup = df.duplicated('participant_id', keep=False)
duplicated = df[dup]
dup_mean = duplicated.groupby(['participant_id'], as_index=False).aggregate(np.mean)
df = df.drop_duplicates(['participant_id'], keep=False)
df = pd.concat([df, dup_mean])
df = df.set_index('participant_id')

# %%
y_df = metadata[['specimen', 'was_preterm', 'participant_id']]
y_df = y_df.drop_duplicates(['participant_id'], keep='first')
y_df = y_df.set_index('participant_id')
y_df = y_df.drop(columns = ['specimen'])

y_df = y_df.loc[df.index]

# %% [markdown]
# # Load selected features, alph, cst and race one hot

# %%
race_features = np.array(race_meta.columns[:6])
alpha_cst_features = np.load('alpha_cst_features.npy')
selected_features = np.load('selected_features.npy')

# %%
all_features = np.concatenate((alpha_cst_features, selected_features))

# %% [markdown]
# # Model selection using lazyclassifier
# ## When model selection, we don't use race features

# %%
kf = StratifiedKFold(n_splits=5, random_state = 1)
models = []
for train_idx, val_idx in kf.split(df.index, y_df):
    train_id = np.array(df.index)[train_idx]
    val_id = np.array(df.index)[val_idx]

    train = df.loc[train_id]
    val = df.loc[val_id]

    X_train = train[all_features]
    X_val = val[all_features]

    y_train = np.array(y_df.loc[train_id])
    y_val = np.array(y_df.loc[val_id])
    
    clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
    model, predictions = clf.fit(X_train, X_val, y_train, y_val)
    models.append(model)
# Out:
# 100%|██████████| 29/29 [01:58<00:00,  4.09s/it]
# 100%|██████████| 29/29 [02:07<00:00,  4.39s/it]
# 100%|██████████| 29/29 [02:07<00:00,  4.41s/it]
# 100%|██████████| 29/29 [02:09<00:00,  4.45s/it]
# 100%|██████████| 29/29 [00:36<00:00,  1.25s/it]

# %%
models[0]
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# BernoulliNB                        0.95               0.93     0.93      0.95
# NearestCentroid                    0.92               0.90     0.90      0.92
# QuadraticDiscriminantAnalysis      0.90               0.90     0.90      0.90
# PassiveAggressiveClassifier        0.92               0.90     0.90      0.92
# LogisticRegression                 0.92               0.89     0.89      0.92
# SVC                                0.89               0.88     0.88      0.89
# CalibratedClassifierCV             0.90               0.87     0.87      0.90
# GaussianNB                         0.89               0.87     0.87      0.89
# SGDClassifier                      0.87               0.87     0.87      0.87
# LinearSVC                          0.88               0.86     0.86      0.88
# ExtraTreesClassifier               0.84               0.85     0.85      0.85
# Perceptron                         0.83               0.84     0.84      0.84
# RandomForestClassifier             0.82               0.83     0.83      0.82
# RidgeClassifierCV                  0.88               0.83     0.83      0.87
# NuSVC                              0.86               0.83     0.83      0.85
# BaggingClassifier                  0.82               0.82     0.82      0.83
# RidgeClassifier                    0.85               0.79     0.79      0.84
# LGBMClassifier                     0.70               0.75     0.75      0.70
# AdaBoostClassifier                 0.72               0.75     0.75      0.73
# DecisionTreeClassifier             0.72               0.74     0.74      0.73
# ExtraTreeClassifier                0.72               0.73     0.73      0.73
# XGBClassifier                      0.67               0.72     0.72      0.68
# LinearDiscriminantAnalysis         0.79               0.70     0.70      0.77
# KNeighborsClassifier               0.74               0.64     0.64      0.71
# DummyClassifier                    0.58               0.51     0.51      0.58
# LabelSpreading                     0.67               0.50     0.50      0.56
# LabelPropagation                   0.66               0.50     0.50      0.56
#
#                                Time Taken
# Model
# BernoulliNB                          0.10
# NearestCentroid                      0.09
# QuadraticDiscriminantAnalysis        1.90
# PassiveAggressiveClassifier          0.15
# LogisticRegression                   0.30
# SVC                                  0.70
# CalibratedClassifierCV               3.30
# GaussianNB                           0.08
# SGDClassifier                        0.16
# LinearSVC                            1.00
# ExtraTreesClassifier                 0.95
# Perceptron                           0.23
# RandomForestClassifier               0.70
# RidgeClassifierCV                    3.06
# NuSVC                                0.94
# BaggingClassifier                    0.64
# RidgeClassifier                      0.36
# LGBMClassifier                      80.71
# AdaBoostClassifier                   0.65
# DecisionTreeClassifier               0.16
# ExtraTreeClassifier                  0.06
# XGBClassifier                       18.62
# LinearDiscriminantAnalysis           2.57
# KNeighborsClassifier                 0.57
# DummyClassifier                      0.06
# LabelSpreading                       0.21
# LabelPropagation                     0.19

# %%
models[1]
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# CalibratedClassifierCV             0.77               0.70     0.70      0.76
# PassiveAggressiveClassifier        0.78               0.69     0.69      0.76
# NearestCentroid                    0.77               0.68     0.68      0.75
# LinearSVC                          0.77               0.67     0.67      0.75
# LogisticRegression                 0.76               0.66     0.66      0.73
# SVC                                0.67               0.65     0.65      0.68
# Perceptron                         0.70               0.63     0.63      0.69
# RidgeClassifierCV                  0.74               0.62     0.62      0.70
# RidgeClassifier                    0.74               0.62     0.62      0.70
# NuSVC                              0.64               0.61     0.61      0.65
# GaussianNB                         0.67               0.60     0.60      0.66
# SGDClassifier                      0.65               0.60     0.60      0.65
# BaggingClassifier                  0.69               0.58     0.58      0.66
# KNeighborsClassifier               0.72               0.57     0.57      0.65
# ExtraTreesClassifier               0.71               0.56     0.56      0.64
# ExtraTreeClassifier                0.65               0.56     0.56      0.63
# AdaBoostClassifier                 0.65               0.55     0.55      0.63
# RandomForestClassifier             0.68               0.55     0.55      0.63
# LinearDiscriminantAnalysis         0.65               0.53     0.53      0.61
# DummyClassifier                    0.58               0.51     0.51      0.58
# LabelSpreading                     0.68               0.51     0.51      0.56
# LabelPropagation                   0.68               0.51     0.51      0.56
# BernoulliNB                        0.63               0.50     0.50      0.58
# XGBClassifier                      0.57               0.49     0.49      0.56
# DecisionTreeClassifier             0.54               0.48     0.48      0.54
# LGBMClassifier                     0.55               0.46     0.46      0.54
# QuadraticDiscriminantAnalysis      0.46               0.45     0.45      0.47
#
#                                Time Taken
# Model
# CalibratedClassifierCV               2.57
# PassiveAggressiveClassifier          0.15
# NearestCentroid                      0.11
# LinearSVC                            0.75
# LogisticRegression                   0.29
# SVC                                  0.68
# Perceptron                           0.12
# RidgeClassifierCV                    2.46
# RidgeClassifier                      0.27
# NuSVC                                1.03
# GaussianNB                           0.09
# SGDClassifier                        0.16
# BaggingClassifier                    1.03
# KNeighborsClassifier                 0.57
# ExtraTreesClassifier                 0.81
# ExtraTreeClassifier                  0.09
# AdaBoostClassifier                   0.78
# RandomForestClassifier               0.69
# LinearDiscriminantAnalysis           2.59
# DummyClassifier                      0.08
# LabelSpreading                       0.22
# LabelPropagation                     0.19
# BernoulliNB                          0.13
# XGBClassifier                       20.52
# DecisionTreeClassifier               0.25
# LGBMClassifier                      88.66
# QuadraticDiscriminantAnalysis        1.95

# %%
models[2]
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# SVC                                0.80               0.78     0.78      0.80
# GaussianNB                         0.81               0.76     0.76      0.81
# Perceptron                         0.81               0.76     0.76      0.80
# LinearSVC                          0.82               0.75     0.75      0.81
# CalibratedClassifierCV             0.81               0.75     0.75      0.80
# PassiveAggressiveClassifier        0.81               0.75     0.75      0.80
# NearestCentroid                    0.79               0.74     0.74      0.79
# LogisticRegression                 0.81               0.74     0.74      0.80
# QuadraticDiscriminantAnalysis      0.74               0.73     0.73      0.75
# NuSVC                              0.74               0.70     0.70      0.74
# SGDClassifier                      0.74               0.70     0.70      0.74
# RidgeClassifierCV                  0.78               0.69     0.69      0.76
# ExtraTreesClassifier               0.72               0.69     0.69      0.72
# RidgeClassifier                    0.76               0.68     0.68      0.74
# BernoulliNB                        0.70               0.67     0.67      0.70
# KNeighborsClassifier               0.77               0.65     0.65      0.73
# LinearDiscriminantAnalysis         0.73               0.64     0.64      0.71
# BaggingClassifier                  0.68               0.64     0.64      0.68
# RandomForestClassifier             0.63               0.61     0.61      0.64
# ExtraTreeClassifier                0.60               0.58     0.58      0.61
# XGBClassifier                      0.55               0.55     0.55      0.56
# AdaBoostClassifier                 0.56               0.55     0.55      0.57
# LGBMClassifier                     0.53               0.54     0.54      0.55
# DecisionTreeClassifier             0.54               0.53     0.53      0.56
# LabelSpreading                     0.69               0.52     0.52      0.58
# LabelPropagation                   0.69               0.52     0.52      0.58
# DummyClassifier                    0.58               0.51     0.51      0.58
#
#                                Time Taken
# Model
# SVC                                  0.71
# GaussianNB                           0.09
# Perceptron                           0.16
# LinearSVC                            1.04
# CalibratedClassifierCV               3.68
# PassiveAggressiveClassifier          0.13
# NearestCentroid                      0.09
# LogisticRegression                   0.28
# QuadraticDiscriminantAnalysis        1.80
# NuSVC                                0.99
# SGDClassifier                        0.15
# RidgeClassifierCV                    3.35
# ExtraTreesClassifier                 0.75
# RidgeClassifier                      0.27
# BernoulliNB                          0.10
# KNeighborsClassifier                 0.58
# LinearDiscriminantAnalysis           2.86
# BaggingClassifier                    0.78
# RandomForestClassifier               0.66
# ExtraTreeClassifier                  0.09
# XGBClassifier                       20.54
# AdaBoostClassifier                   0.78
# LGBMClassifier                      87.22
# DecisionTreeClassifier               0.21
# LabelSpreading                       0.24
# LabelPropagation                     0.15
# DummyClassifier                      0.08

# %%
models[3]
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# QuadraticDiscriminantAnalysis      0.84               0.78     0.78      0.83
# PassiveAggressiveClassifier        0.82               0.72     0.72      0.80
# SVC                                0.78               0.72     0.72      0.77
# LinearSVC                          0.81               0.71     0.71      0.79
# CalibratedClassifierCV             0.81               0.70     0.70      0.78
# NuSVC                              0.73               0.68     0.68      0.73
# RidgeClassifier                    0.79               0.67     0.67      0.75
# RidgeClassifierCV                  0.77               0.63     0.63      0.72
# LinearDiscriminantAnalysis         0.75               0.63     0.63      0.70
# SGDClassifier                      0.72               0.58     0.58      0.66
# GaussianNB                         0.72               0.57     0.57      0.65
# Perceptron                         0.72               0.57     0.57      0.65
# ExtraTreeClassifier                0.67               0.55     0.55      0.63
# ExtraTreesClassifier               0.71               0.54     0.54      0.61
# LogisticRegression                 0.71               0.54     0.54      0.61
# NearestCentroid                    0.70               0.53     0.53      0.59
# RandomForestClassifier             0.69               0.52     0.52      0.57
# KNeighborsClassifier               0.69               0.51     0.51      0.57
# BernoulliNB                        0.69               0.51     0.51      0.57
# DummyClassifier                    0.58               0.51     0.51      0.58
# BaggingClassifier                  0.67               0.51     0.51      0.58
# LGBMClassifier                     0.65               0.51     0.51      0.58
# LabelSpreading                     0.68               0.50     0.50      0.55
# LabelPropagation                   0.68               0.50     0.50      0.55
# XGBClassifier                      0.65               0.50     0.50      0.57
# AdaBoostClassifier                 0.63               0.49     0.49      0.57
# DecisionTreeClassifier             0.56               0.45     0.45      0.53
#
#                                Time Taken
# Model
# QuadraticDiscriminantAnalysis        1.48
# PassiveAggressiveClassifier          0.13
# SVC                                  0.79
# LinearSVC                            0.89
# CalibratedClassifierCV               3.30
# NuSVC                                1.03
# RidgeClassifier                      0.26
# RidgeClassifierCV                    2.57
# LinearDiscriminantAnalysis           2.52
# SGDClassifier                        0.21
# GaussianNB                           0.09
# Perceptron                           0.11
# ExtraTreeClassifier                  0.09
# ExtraTreesClassifier                 1.00
# LogisticRegression                   0.42
# NearestCentroid                      0.13
# RandomForestClassifier               0.78
# KNeighborsClassifier                 0.55
# BernoulliNB                          0.18
# DummyClassifier                      0.08
# BaggingClassifier                    1.12
# LGBMClassifier                      90.08
# LabelSpreading                       0.21
# LabelPropagation                     0.16
# XGBClassifier                       19.84
# AdaBoostClassifier                   0.77
# DecisionTreeClassifier               0.21

# %%
models[4]
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# Perceptron                         0.76               0.62     0.62      0.70
# GaussianNB                         0.74               0.60     0.60      0.68
# CalibratedClassifierCV             0.73               0.59     0.59      0.67
# LinearSVC                          0.73               0.59     0.59      0.67
# PassiveAggressiveClassifier        0.73               0.58     0.58      0.66
# SGDClassifier                      0.69               0.58     0.58      0.65
# RidgeClassifierCV                  0.71               0.56     0.56      0.64
# LogisticRegression                 0.72               0.56     0.56      0.63
# SVC                                0.67               0.55     0.55      0.63
# DecisionTreeClassifier             0.71               0.55     0.55      0.62
# RidgeClassifier                    0.69               0.55     0.55      0.62
# QuadraticDiscriminantAnalysis      0.66               0.54     0.54      0.62
# LinearDiscriminantAnalysis         0.67               0.53     0.53      0.61
# NearestCentroid                    0.69               0.52     0.52      0.58
# BaggingClassifier                  0.69               0.51     0.51      0.57
# NuSVC                              0.61               0.51     0.51      0.59
# ExtraTreeClassifier                0.67               0.51     0.51      0.58
# XGBClassifier                      0.69               0.51     0.51      0.56
# ExtraTreesClassifier               0.68               0.50     0.50      0.55
# LabelSpreading                     0.68               0.50     0.50      0.55
# BernoulliNB                        0.68               0.50     0.50      0.55
# LabelPropagation                   0.68               0.50     0.50      0.55
# RandomForestClassifier             0.68               0.50     0.50      0.55
# KNeighborsClassifier               0.68               0.50     0.50      0.55
# LGBMClassifier                     0.68               0.50     0.50      0.55
# AdaBoostClassifier                 0.67               0.49     0.49      0.55
# DummyClassifier                    0.53               0.45     0.45      0.53
#
#                                Time Taken
# Model
# Perceptron                           0.13
# GaussianNB                           0.10
# CalibratedClassifierCV               3.51
# LinearSVC                            0.98
# PassiveAggressiveClassifier          0.14
# SGDClassifier                        0.19
# RidgeClassifierCV                    1.79
# LogisticRegression                   0.29
# SVC                                  0.76
# DecisionTreeClassifier               0.21
# RidgeClassifier                      0.24
# QuadraticDiscriminantAnalysis        1.52
# LinearDiscriminantAnalysis           3.76
# NearestCentroid                      0.15
# BaggingClassifier                    0.91
# NuSVC                                1.02
# ExtraTreeClassifier                  0.09
# XGBClassifier                       16.00
# ExtraTreesClassifier                 0.84
# LabelSpreading                       0.31
# BernoulliNB                          0.17
# LabelPropagation                     0.19
# RandomForestClassifier               0.74
# KNeighborsClassifier                 0.54
# LGBMClassifier                       0.62
# AdaBoostClassifier                   0.76
# DummyClassifier                      0.08

# %% [markdown]
# # Model training
# ## Simply add race feature for selected model training

# %%
all_features = np.concatenate((selected_features, alpha_cst_features, race_features))

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(1) # Seed 고정

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, f1_score, precision_score, recall_score, balanced_accuracy_score

def cal_mat(preds, labels):
    
    result = {}
    result['acc'] = accuracy_score(labels, preds)
    result['AUC'] = roc_auc_score(labels, preds)
    result['macro f1'] = f1_score(labels, preds, average='macro')
    result['precision'] = precision_score(labels, preds)
    result['recall'] = recall_score(labels, preds)
    result['bal_acc'] = balanced_accuracy_score(labels, preds)
    
    return result

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.calibration import CalibratedClassifierCV
from sklearn.svm import SVC, LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.ensemble import VotingClassifier
from joblib import dump, load

seed = 1

kf = StratifiedKFold(n_splits=5, random_state = seed)
i = 1

indexes = []
pred_labels = []
pred_probability = []

acc_results = []
auc_results = []
for train_idx, val_idx in kf.split(y_df.index, y_df):
    train_id = np.array(y_df.index)[train_idx]
    val_id = np.array(y_df.index)[val_idx]

    train = df.loc[train_id]
    val = df.loc[val_id]

    X_train = train[all_features]
    X_val = val[all_features]

    y_train = np.array(y_df.loc[train_id])
    y_val = np.array(y_df.loc[val_id])

    clf1 = make_pipeline(StandardScaler(), QuadraticDiscriminantAnalysis())
    
    clf3 = make_pipeline(StandardScaler(), CalibratedClassifierCV())

    lsvc = make_pipeline(StandardScaler(), LinearSVC())
    clf4 = CalibratedClassifierCV(lsvc, cv=10, method='isotonic')

    clf6 = make_pipeline(StandardScaler(), SVC(gamma='auto', probability=True))

    pac = make_pipeline(StandardScaler(), PassiveAggressiveClassifier())
    clf7 = CalibratedClassifierCV(pac, cv=10, method='isotonic')
    
    lgr = make_pipeline(StandardScaler(), LogisticRegression())
    clf8 = CalibratedClassifierCV(lgr, cv=10, method='isotonic')


    eclf = VotingClassifier(estimators = [
                                          ('qda', clf1), 
                                          ('cbc', clf3), 
                                          ('lsvc', clf4),
                                          ('svc', clf6),
                                          ('pac', clf7),
                                          ('lgr', clf8),
                                                            ],
                                            voting='soft')

    eclf = eclf.fit(np.array(X_train), y_train)

    preds = eclf.predict(np.array(X_val))
    probability = eclf.predict_proba(np.array(X_val))

    result = cal_mat(preds, y_val)
    print(result)
    acc_results.append(result['acc'])
    auc_results.append(result['AUC'])
    dump(eclf, f'Models/model_{i}.save')
    i += 1
    
    indexes.append(val_id)
    pred_labels.append(preds)
    pred_probability.append(probability[:,1])
    
print('Average acc:', sum(acc_results) / 5)
print('Average AUC:', sum(auc_results) / 5)
print('______________________________________________________________')
# Out:
# {'acc': 0.9176954732510288, 'AUC': 0.9055944055944056, 'macro f1': 0.9055944055944056, 'precision': 0.8717948717948718, 'recall': 0.8717948717948718, 'bal_acc': 0.9055944055944056}
# {'acc': 0.7242798353909465, 'AUC': 0.6617715617715618, 'macro f1': 0.6680666272503006, 'precision': 0.5846153846153846, 'recall': 0.48717948717948717, 'bal_acc': 0.6617715617715617}
# {'acc': 0.8189300411522634, 'AUC': 0.7821678321678323, 'macro f1': 0.7878571428571429, 'precision': 0.7361111111111112, 'recall': 0.6794871794871795, 'bal_acc': 0.7821678321678323}
# {'acc': 0.8353909465020576, 'AUC': 0.7435897435897436, 'macro f1': 0.7735321528424977, 'precision': 1.0, 'recall': 0.48717948717948717, 'bal_acc': 0.7435897435897436}
# {'acc': 0.7355371900826446, 'AUC': 0.5948051948051948, 'macro f1': 0.584192439862543, 'precision': 0.8421052631578947, 'recall': 0.2077922077922078, 'bal_acc': 0.5948051948051948}
# Average acc: 0.8063666972757882
# Average AUC: 0.7375857475857476
# ______________________________________________________________
